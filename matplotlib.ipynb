# %%
import matplotlib.pyplot as plt

# %%
# Explanation:
# fig, ax = plt.subplots()

# Creates a figure (fig) and an axis (ax).
# The figure is the entire window or canvas, while the axis is the area where the graph is drawn.
# ax.plot([1, 2, 3], [2, 7, 8])

# Plots the points (1,2), (2,7), and (3,8) on the graph.
# The x-values are [1, 2, 3] and the y-values are [2, 7, 8].
# ax.set_title("PLOT")

# Sets the title of the axis.
# plt.title("PLOT") is incorrect when using ax.plot() (object-oriented approach).
# plt.show()

# Displays the graph.

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3],[2,7,8,])
ax.set_title("PLOT")
#plt.title("PLOT")
plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2)

print(fig.axes)
# Out:
# [<Axes: >, <Axes: >, <Axes: >, <Axes: >]
